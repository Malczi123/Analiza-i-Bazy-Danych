# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt


df = pd.read_csv('SCORES.csv', sep = ',')

# %%
df
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
df.sort_values(['Hours'])
# Out:
#     Hours  Scores
# 14    1.1      17
# 5     1.5      20
# 17    1.9      24
# 0     2.5      21
# 16    2.5      30
# 20    2.7      30
# 9     2.7      25
# 2     3.2      27
# 13    3.3      42
# 4     3.5      30
# 22    3.8      35
# 12    4.5      41
# 21    4.8      54
# 1     5.1      47
# 7     5.5      60
# 11    5.9      62
# 18    6.1      67
# 23    6.9      76
# 19    7.4      69
# 10    7.7      85
# 24    7.8      86
# 8     8.3      81
# 3     8.5      75
# 15    8.9      95
# 6     9.2      88

# %%
x = [i for i in range(len(df['Hours']))]

# %%
#Wstepny wykres uzyskanych danych
plt.scatter(df['Hours'],df['Scores'])
plt.grid()
plt.title("Wynik uzyskany na tescie w porownaniu do czasu poswieconego na nauke")
plt.xlabel('Ilosc poswieconych godzin na nauke')
plt.ylabel('Wynik uzyskany na tescie')
plt.show()

# %%
matrix = df.to_numpy()
matrix
# Out:
# array([[ 2.5, 21. ],
#        [ 5.1, 47. ],
#        [ 3.2, 27. ],
#        [ 8.5, 75. ],
#        [ 3.5, 30. ],
#        [ 1.5, 20. ],
#        [ 9.2, 88. ],
#        [ 5.5, 60. ],
#        [ 8.3, 81. ],
#        [ 2.7, 25. ],
#        [ 7.7, 85. ],
#        [ 5.9, 62. ],
#        [ 4.5, 41. ],
#        [ 3.3, 42. ],
#        [ 1.1, 17. ],
#        [ 8.9, 95. ],
#        [ 2.5, 30. ],
#        [ 1.9, 24. ],
#        [ 6.1, 67. ],
#        [ 7.4, 69. ],
#        [ 2.7, 30. ],
#        [ 4.8, 54. ],
#        [ 3.8, 35. ],
#        [ 6.9, 76. ],
#        [ 7.8, 86. ]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(matrix[:,0],matrix[:,1],train_size=0.3)

# %%
x_train
# Out:
# array([4.5, 7.4, 3.2, 4.8, 7.8, 1.9, 6.9])

# %%
y_train
# Out:
# array([41., 69., 27., 54., 86., 24., 76.])

# %%
x_test
# Out:
# array([5.1, 6.1, 7.7, 8.3, 9.2, 5.9, 2.5, 1.1, 5.5, 1.5, 3.8, 2.7, 8.9,
#        2.7, 3.5, 8.5, 3.3, 2.5])

# %%
y_test
# Out:
# array([47., 67., 85., 81., 88., 62., 21., 17., 60., 20., 35., 30., 95.,
#        25., 30., 75., 42., 30.])

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(x_train.reshape(-1,1),y_train.reshape(-1,1))
reg.coef_
# Out:
# array([[10.51379638]])

# %%
y_predicted = reg.predict(x_test.reshape(-1,1)) #porownujemy teraz z y_test
y_predicted
# Out:
# array([[52.65556613],
#        [63.16936251],
#        [79.99143673],
#        [86.29971456],
#        [95.7621313 ],
#        [61.06660324],
#        [25.31969553],
#        [10.60038059],
#        [56.86108468],
#        [14.80589914],
#        [38.98763083],
#        [27.4224548 ],
#        [92.60799239],
#        [27.4224548 ],
#        [35.83349191],
#        [88.40247383],
#        [33.73073264],
#        [25.31969553]])

# %%
y_test.reshape(-1,1)
# Out:
# array([[47.],
#        [67.],
#        [85.],
#        [81.],
#        [88.],
#        [62.],
#        [21.],
#        [17.],
#        [60.],
#        [20.],
#        [35.],
#        [30.],
#        [95.],
#        [25.],
#        [30.],
#        [75.],
#        [42.],
#        [30.]])

# %%
#ad 8
x_line = np.linspace(1,10)
y_line = reg.coef_[0]*x_line+reg.intercept_[0]
fig,axs = plt.subplots(2)
axs[0].scatter(df['Hours'],df['Scores'])
axs[0].title.set_text("Wykres oryginalny")
axs[1].scatter(x_test,y_predicted)
axs[1].title.set_text("Wartosci przewidziane przez liniowa regresje")
axs[1].plot(x_line,y_line,'r')

# %%
#ad9
from sklearn.metrics import mean_absolute_error, mean_squared_error
mean_absolute_error(y_test,y_predicted) #sredni blad bezwgledny
# Out:
# 5.061528702822708

# %%
mean_squared_error(y_test,y_predicted) #blad sredniokwadratowy
# Out:
# 33.08205929360716

# %%
np.sqrt(mean_squared_error(y_test,y_predicted)) #pierwiastek bledu sredniokwadratowego
# Out:
# 5.751700556670797

# %%
df2 = pd.read_csv('SBP.csv', sep = ',')
df2
# Out:
#     Age  SBP
# 0    60  117
# 1    61  120
# 2    74  145
# 3    57  129
# 4    63  132
# 5    68  130
# 6    66  127
# 7    77  163
# 8    63  136
# 9    54  115
# 10   63  118
# 11   76  132
# 12   60  111
# 13   61  112
# 14   65  147
# 15   79  138
# 16   69  141
# 17   56  124
# 18   62  122

# %%
df2.sort_values(['Age'])

#Wstepny wykres uzyskanych danych
plt.scatter(df2['Age'],df2['SBP'])
plt.grid()
plt.title("Cisnienie w zaleznosci od wieku")
plt.xlabel('Wiek')
plt.ylabel('Cisnienie')
plt.show()

# %%
matrix2 = df2.to_numpy()
matrix2
# Out:
# array([[ 60, 117],
#        [ 61, 120],
#        [ 74, 145],
#        [ 57, 129],
#        [ 63, 132],
#        [ 68, 130],
#        [ 66, 127],
#        [ 77, 163],
#        [ 63, 136],
#        [ 54, 115],
#        [ 63, 118],
#        [ 76, 132],
#        [ 60, 111],
#        [ 61, 112],
#        [ 65, 147],
#        [ 79, 138],
#        [ 69, 141],
#        [ 56, 124],
#        [ 62, 122]], dtype=int64)

# %%
x_train2,x_test2,y_train2,y_test2 = train_test_split(matrix2[:,0],matrix2[:,1],train_size=0.3)
x_test2
# Out:
# array([79, 60, 76, 65, 60, 74, 69, 61, 54, 77, 63, 56, 66, 63],
#       dtype=int64)

# %%
reg2 = LinearRegression().fit(x_train2.reshape(-1,1),y_train2.reshape(-1,1))
y_predicted2 = reg2.predict(x_test2.reshape(-1,1)) #porownujemy teraz z y_test
y_predicted2
# Out:
# array([[133.02547771],
#        [123.94904459],
#        [131.59235669],
#        [126.33757962],
#        [123.94904459],
#        [130.63694268],
#        [128.24840764],
#        [124.42675159],
#        [121.08280255],
#        [132.07006369],
#        [125.38216561],
#        [122.03821656],
#        [126.81528662],
#        [125.38216561]])

# %%
x_line2 = np.linspace(52,81)
y_line2 = reg2.coef_[0]*x_line2+reg2.intercept_[0]
fig,axs = plt.subplots(2)
axs[0].scatter(df2['Age'],df2['SBP'])
axs[0].title.set_text("Wykres oryginalny")
axs[1].scatter(x_test2,y_predicted2)
axs[1].title.set_text("Wartosci przewidziane przez liniowa regresje")
axs[1].plot(x_line2,y_line2,'r')

# %%
#Zadanie 2

df3 = pd.read_csv('PETROL.csv',sep=',')

# %%
df3
# Out:
#     Podatek_paliwowy  Sredni_przychod  Utwardzone_autostrady  \
# 0               9.00             3571                   1976
# 1               9.00             4092                   1250
# 2               9.00             3865                   1586
# 3               7.50             4870                   2351
# 4               8.00             4399                    431
# 5              10.00             5342                   1333
# 6               8.00             5319                  11868
# 7               8.00             5126                   2138
# 8               8.00             4447                   8577
# 9               7.00             4512                   8507
# 10              8.00             4391                   5939
# 11              7.50             5126                  14186
# 12              7.00             4817                   6930
# 13              7.00             4207                   6580
# 14              7.00             4332                   8159
# 15              7.00             4318                  10340
# 16              7.00             4206                   8508
# 17              7.00             3718                   4725
# 18              7.00             4716                   5915
# 19              8.50             4341                   6010
# 20              7.00             4593                   7834
# 21              8.00             4983                    602
# 22              9.00             4897                   2449
# 23              9.00             4258                   4686
# 24              8.50             4574                   2619
# 25              9.00             3721                   4746
# 26              8.00             3448                   5399
# 27              7.50             3846                   9061
# 28              8.00             4188                   5975
# 29              9.00             3601                   4650
# 30              7.00             3640                   6905
# 31              7.00             3333                   6594
# 32              8.00             3063                   6524
# 33              7.50             3357                   4121
# 34              8.00             3528                   3495
# 35              6.58             3802                   7834
# 36              5.00             4045                  17782
# 37              7.00             3897                   6385
# 38              8.50             3635                   3274
# 39              7.00             4345                   3905
# 40              7.00             4449                   4639
# 41              7.00             3656                   3985
# 42              7.00             4300                   3635
# 43              7.00             3745                   2611
# 44              6.00             5215                   2302
# 45              9.00             4476                   3942
# 46              7.00             4296                   4083
# 47              7.00             5002                   9794
#
#     Procent_ludnosci_z_prawem_jazdy  Zuzycie_paliwa
# 0                             0.525             541
# 1                             0.572             524
# 2                             0.580             561
# 3                             0.529             414
# 4                             0.544             410
# 5                             0.571             457
# 6                             0.451             344
# 7                             0.553             467
# 8                             0.529             464
# 9                             0.552             498
# 10                            0.530             580
# 11                            0.525             471
# 12                            0.574             525
# 13                            0.545             508
# 14                            0.608             566
# 15                            0.586             635
# 16                            0.572             603
# 17                            0.540             714
# 18                            0.724             865
# 19                            0.677             640
# 20                            0.663             649
# 21                            0.602             540
# 22                            0.511             464
# 23                            0.517             547
# 24                            0.551             460
# 25                            0.544             566
# 26                            0.548             577
# 27                            0.579             631
# 28                            0.563             574
# 29                            0.493             534
# 30                            0.518             571
# 31                            0.513             554
# 32                            0.578             577
# 33                            0.547             628
# 34                            0.487             487
# 35                            0.629             644
# 36                            0.566             640
# 37                            0.586             704
# 38                            0.663             648
# 39                            0.672             968
# 40                            0.626             587
# 41                            0.563             699
# 42                            0.603             632
# 43                            0.508             591
# 44                            0.672             782
# 45                            0.571             510
# 46                            0.623             610
# 47                            0.593             524
